# %%
import pandas as pd

# %%
df = pd.read_csv('data/all_events.csv', index_col=0)

# %%
df.rename(columns={'lon':'lat', 'lat':'lon'}, inplace=True)
df = df[['tipo_evento', 'nombre_evento', 'descripcion', 'direccion', 'lon', 'lat', 'contacto', 'accesibilidad', 'precio',
'fecha_inicio', 'fecha_fin', 'imagen_url', 'ciudad']]
df.head()
# Out:
#     tipo_evento                                      nombre_evento  \
# 0          Arte  Meet Vincent van Gogh: una experiencia inmersi...
# 1  Candlelights      Candlelight Open Air: Bandas Sonoras Mágicas
# 2  Candlelights   Candlelight Open Air: Tributo a Daft Punk a l...
# 3  Candlelights   Candlelight: El Cascanueces y ballet a la luz...
# 4  Candlelights   Candlelight: Verdi, La Traviata bajo la luz d...
#
#                                          descripcion  \
# 0  Embárcate en un viaje inspirador al incomparab...
# 1  Vive una experiencia musical única durante est...
# 2  ¡Los mejores temas de Daft Punk! Laura Andrés ...
# 3  Vive un auténtico homenaje a artistas clásicos...
# 4  La Traviata, una de las óperas que más persona...
#
#                                            direccion       lon        lat  \
# 0  Espacio Ibercaja Delicias - Paseo de las Delic... -3.690158  40.397862
# 1                                        Teatro Goya -3.725237  40.407762
# ...

# %%
for i, val in enumerate(list(df.accesibilidad)):
    if len(val) > 200:
        print(i)

# %%
df.descripcion[18]
# Out:
# 'Porque los clásicos nunca mueren ... ¡El Teatro Goya ha sido el escenario elegido para una serie de conciertos tributo a algunos de los mejores cantantes y bandas de todos los tiempos! En un hermoso espacio aire libre rodeado de verde naturaleza, en esta ocasión te sumergirás en un tributo sin precedentes a Queen. Revive sus grandes clásicos en esta experiencia musical única. ¡No te pierdas este evento exclusivo!\n\n'

# %%
len('''Cruz de Navajas: Mecano Musical Experience es un espectáculo que contiene múltiples historias, 
que escucharás y visualizarás en forma de pequeños universos.''')
# Out:
# 157

# %%
df.descripcion[18] = '''Ven al Teatro Goya para disfrutar de una serie de conciertos tributo! En un hermoso espacio aire libre rodeado de naturaleza, \nen esta ocasión te sumergirás en un tributo sin precedentes a Queen.'''
# Out:
# C:\Users\jgnsa\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.to_csv('data/all_events.csv')

# %%
df.descripcion = df.descripcion.apply(lambda x: x.replace('\n', ''))
df.precio = df.precio.apply(lambda x: x + ' €')
df
# Out:
#      tipo_evento                                      nombre_evento  \
# 0           Arte  Meet Vincent van Gogh: una experiencia inmersi...
# 1   Candlelights      Candlelight Open Air: Bandas Sonoras Mágicas
# 2   Candlelights   Candlelight Open Air: Tributo a Daft Punk a l...
# 3   Candlelights   Candlelight: El Cascanueces y ballet a la luz...
# 4   Candlelights   Candlelight: Verdi, La Traviata bajo la luz d...
# 5   Candlelights   Candlelight Jazz Open Air: Tributo a Nina Sim...
# 6   Candlelights   Candlelight: Bandas Sonoras, cuarteto de cuer...
# 7   Candlelights   Candlelight: Verdi, La Traviata bajo la luz d...
# 8   Candlelights   Candlelight: Las cuatro estaciones de Vivaldi...
# 9   Candlelights   Candlelight Open Air: Morricone y otras banda...
# 10      Outdoors   Corona Paradise: la experiencia interactiva m...
# 11      Tributos         Tributos: Lo mejor de Queen al aire libre
# 12      Tributos   Tributos: lo mejor de The Beatles al aire libre
# ...

# %%
natur_df = pd.read_json('natur_clean_plus.json')
natur_df.head()
# Out:
#                              nombre_evento id_evento tipo_evento  \
# 0      Camino Natural del Valle del Lozoya        N1  Naturaleza
# 1                       Parque de las eras        N2  Naturaleza
# 2  Rosaleda Ramón Ortiz - Parque del Oeste        N3  Naturaleza
# 3                        Senda de Valmores        N4  Naturaleza
# 4          Senda del río Hayedo de Montejo        N5  Naturaleza
#
#                                            direccion     long       lat  \
# 0  Kilómetro 27,6 de la carretera M-604. El Camin... -3.88674  40.88710
# 1  Calle de las eras, 28189. El Atazar, Madrid (M... -3.47213  40.93486
# 2              Calle de la Rosaleda, 1. 28008. Marid -3.72191  40.42649
# 3         Calle Palacio, 28514. Nuevo Baztán, Madrid -3.24418  40.36957
# 4  Carretera m-139, Km 5,8 28190. Montejo de la S... -3.52628  41.06027
#
#                                             contacto  \
# 0  https://www.mapa.gob.es/es/desarrollo-rural/te...
# ...

# %%
for i, val in enumerate(list(natur_df.contacto)):
    if len(val) > 100:
        print(i)

# %%
natur_df.contacto[7]
# Out:
# 'https://www.comunidad.madrid/actividades/2017/senda-soto-bayona-cortados-titulcia'

# %%
len("""www.comunidad.madrid/actividades/2017/senda-soto-bayona-cortados-titulcia""")
# Out:
# 73

# %%
natur_df.contacto[0] = """www.mapa.gob.es/es/desarrollo-rural/temas/caminos-naturales/"""
# Out:
# C:\Users\jgnsa\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
natur_df['fecha_inicio'] = ['2021-07-22']*len(natur_df)
natur_df['fecha_fin'] = ['2050-07-22']*len(natur_df)
natur_df['ciudad'] = ['Comunidad de Madrid']*len(natur_df)
natur_df['precio'] = ['Gratuito']*len(natur_df)

# %%
natur_df.rename(columns={'long':'lon'}, inplace=True)

# %%
natur_df = natur_df[['tipo_evento', 'nombre_evento', 'descripcion', 'direccion', 'lon', 'lat', 'contacto', 'accesibilidad', 'precio',
'fecha_inicio', 'fecha_fin', 'imagen_url', 'ciudad']]

# %%
natur_df.descripcion = natur_df.descripcion.apply(lambda x: x.replace('\n', ''))
natur_df.accesibilidad = natur_df.accesibilidad.apply(lambda x: x.replace('\n', ''))

# %%
natur_df
# Out:
#    tipo_evento                                     nombre_evento  \
# 0   Naturaleza               Camino Natural del Valle del Lozoya
# 1   Naturaleza                                Parque de las eras
# 2   Naturaleza           Rosaleda Ramón Ortiz - Parque del Oeste
# 3   Naturaleza                                 Senda de Valmores
# 4   Naturaleza                   Senda del río Hayedo de Montejo
# 5   Naturaleza                                  Senda para todos
# 6   Naturaleza                Senda Verde Dehesa de NAVALQUEJIGO
# 7   Naturaleza   Senda de Soto Bayona Y Los Cortados de Titulcia
# 8   Naturaleza      Jardín botánico de la Sierra Norte de Madrid
# 9   Naturaleza                   Senda verde Rascafría El Paular
# 10  Naturaleza                        Arboreto Giner de Los Ríos
# 11  Naturaleza                        Parque Natural de Peñalara
# 12  Naturaleza  Parque regional de la Cuenca Alta del Manzanares
# ...

# %%
museos = pd.read_csv('Museos/info_museos_madrid.csv', index_col=0)
museos
# Out:
#    id_evento tipo_evento                                nombre_evento  \
# 0          0       Museo    Museo Nacional Centro de Arte Reina Sofía
# 1          1       Museo                     Museo Nacional del Prado
# 2          2       Museo                       Palacio Real de Madrid
# 3          3       Museo                     Palacio Real de Aranjuez
# 4          4       Museo  Real Monasterio de San Lorenzo del Escorial
#
#                                          descripcion  \
# 0  Uno de los más importantes museos de arte de E...
# 1  El Museo Nacional del Prado posee en la actual...
# 2  El Palacio Real de Madrid es la residencia ofi...
# 3  Residencia de primavera de los monarcas españo...
# 4  El Monasterio de El Escorial, construido entre...
#
#                                            direccion      long        lat  \
# 0                   C/ Santa Isabel, 52 28012 Madrid -3.694600  40.408051
# ...

# %%
for i, val in enumerate(list(museos.accesibilidad)):
    if len(val) > 200:
        print(i)
# Out:
# 3

# %%
museos.accesibilidad[3]
# Out:
# 'La entrada por la que el público general accede al Palacio tiene cuatro escalones, dos de 10 cm\ny dos de 18 cm.\nLos usuarios en silla de ruedas acceden por una entrada alternativa, situada en la fachada late-\nral del Palacio y que corresponde con la salida de todos los visitantes.\nLa entrada tiene una rampa de 1,50 m de ancho, 1,94 m de longitud y una inclinación pronun-\nciada del 17,6%. No tiene pasamanos pero si un zócalo de protección a cada lado de 77 cm de\naltura.'

# %%
len("""San Lorenzo del Escorial (Madrid)""")
# Out:
# 33

# %%
museos.accesibilidad[3] = """La entrada tiene una rampa de 1,50 m de ancho, 1,94 m de longitud y una inclinación pronunciada del 17,6%. No tiene pasamanos pero si un zócalo 
de protección a cada lado de 77 cm de altura."""
# Out:
# C:\Users\jgnsa\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
museos['ciudad'] = ['Madrid', 'Madrid', 'Madrid', 'Aranjuez (Madrid)', 'San Lorenzo del Escorial (Madrid)']
museos.rename(columns={'long':'lon'}, inplace=True)
museos.fecha_inicio = ['2021-07-22']*len(museos)
museos.fecha_fin = ['2050-07-22']*len(museos)
museos = museos[['tipo_evento', 'nombre_evento', 'descripcion', 'direccion', 'lon', 'lat', 'contacto', 'accesibilidad', 'precio',
'fecha_inicio', 'fecha_fin', 'imagen_url', 'ciudad']]
museos
# Out:
# C:\Users\jgnsa\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\jgnsa\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\jgnsa\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
museos.to_csv('data/all_museums.csv')

# %%
import json
from sqlalchemy import create_engine
import pandas as pd

# Leemos json con las credenciales
with open('settings_sql.json', "r") as json_file_readed:
        json_readed = json.load(json_file_readed)

# Asignamos valores
IP_DNS = json_readed["IP_DNS"]
PORT = json_readed["PORT"]
USER = json_readed["USER"]
PASSWORD = json_readed["PASSWORD"]
BD_NAME = json_readed["BD_NAME"]

SQL_ALCHEMY = 'mysql+pymysql://' + USER + ':' + PASSWORD + '@' + IP_DNS + ':' + str(PORT) + '/' + BD_NAME

# Creamos conexión
engine = create_engine(SQL_ALCHEMY)

# %%
base.to_sql('evento', engine, index=False, if_exists='append')

# %%
base = pd.concat([df, natur_df, museos])
base.descripcion = base.descripcion.apply(lambda x: x.replace('\n', ''))
base.accesibilidad = base.accesibilidad.apply(lambda x: x.replace('\n', ''))
base
# Out:
#      tipo_evento                                      nombre_evento  \
# 0           Arte  Meet Vincent van Gogh: una experiencia inmersi...
# 1   Candlelights      Candlelight Open Air: Bandas Sonoras Mágicas
# 2   Candlelights   Candlelight Open Air: Tributo a Daft Punk a l...
# 3   Candlelights   Candlelight: El Cascanueces y ballet a la luz...
# 4   Candlelights   Candlelight: Verdi, La Traviata bajo la luz d...
# 5   Candlelights   Candlelight Jazz Open Air: Tributo a Nina Sim...
# 6   Candlelights   Candlelight: Bandas Sonoras, cuarteto de cuer...
# 7   Candlelights   Candlelight: Verdi, La Traviata bajo la luz d...
# 8   Candlelights   Candlelight: Las cuatro estaciones de Vivaldi...
# 9   Candlelights   Candlelight Open Air: Morricone y otras banda...
# 10      Outdoors   Corona Paradise: la experiencia interactiva m...
# 11      Tributos         Tributos: Lo mejor de Queen al aire libre
# 12      Tributos   Tributos: lo mejor de The Beatles al aire libre
# ...

# %%
base.to_csv('data/all_data.csv')
