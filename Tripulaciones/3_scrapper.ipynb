# %%
# Libraries

import numpy as np
import pandas as pd
import re
import emoji

import requests
from bs4 import BeautifulSoup
import html
import lxml

# %% [markdown]
# # Sacar eventos de secciones

# %%
def get_events(tuple_):
    section_, url = tuple_

    # Link to the event
    r = requests.get(url)

    # Pulling the data from the link
    soup = BeautifulSoup(r.text, "lxml")

    # Getting all the events
    events = soup.findAll(class_ = "fv-plan-tile")
    event_images = soup.findAll(class_ = "fv-plan-tile__img")

    # It gets the href attribute for every event in the list
    urls = ["https://feverup.com" + event["href"] for event in events]
    images = [image["src"] for image in event_images]
    sections = [section_ for i in range(len(images))]
    
    return list(zip(sections, urls, images))

# %%
section_urls = [("Arte", "https://feverup.com/madrid/cultura-arte-moda"),
                ("Atracciones", "https://feverup.com/madrid/atracciones-tours-viajes"),
                ("Brunch", "https://feverup.com/madrid/brunch"),
                ("Dinner", "https://feverup.com/madrid/find-the-dinner"),
                ("Terrazas", "https://feverup.com/madrid/terrazas-y-rooftops"),
                ("Deportes", "https://feverup.com/madrid/deportes-aventura"),
                ("Conciertos", "https://feverup.com/madrid/conciertos-festivales"),
                ("Actividades", "https://feverup.com/madrid/actividades-juegos"),
                ("Belleza", "https://feverup.com/madrid/actividades-juegos"),
                ("Afterwork", "https://feverup.com/madrid/bebidas-afterwork"),
                ("Clubs", "https://feverup.com/madrid/vida-nocturna-clubs"),
                ("Aire_libre", "https://feverup.com/madrid/planes-aire-libre"),
                ("Candlelights", "https://feverup.com/madrid/candlelight"),
                ("Tributos", "https://feverup.com/madrid/conciertos-tributo"),
                ("Gastronomía", "https://feverup.com/madrid/gastronomia"),
                ("Cine", "https://feverup.com/madrid/cine"),
                ("Teatro", "https://feverup.com/madrid/teatro-comedia-espectaculos")]

arte_urls = get_events(section_urls[0])

# %% [markdown]
# # Procesador de eventos

# %%
#### Function 1
def get_data(url):
    # Link to the event
    r = requests.get(url)
    # Pulling the data from the link
    soup = BeautifulSoup(r.text, "lxml")
    # Take event title and description
    # In the event description is where "accesibility" info is located
    event_title = soup.find(class_ = "plan-hero__title").text
    event_descr = soup.find(class_ = "plan-description mb-32")
    # Transform the event description into string for later processing
    event_descr = str(event_descr)
    # Get price info
    event_price = soup.find(class_ = "sidebarBuyingText sidebarWrapper__btn").text
    event_price = event_price.split("\xa0€")[0]

    return event_title, event_descr, event_price

#### Function 2
def separate_sections(event_descr):
    # 1) Split the data using the "<strong>" tag -> This way we separate the sections
    # 2) Split the data using the "</strong>" tag -> This way we separate titles from descriptions
    event_descr_items = [elem.split("</strong>") for elem in event_descr.split("<strong>")]

    return event_descr_items

#### Function 3
def separate_title_descr(event_descr_items):
    # Dict to save the info title-descriptions that we have in a list of lists
    title_descr = {}
    # This is to assign a numerical value as key to those descriptions without section title
    no_title_count = 1

    # Iterate over the list of lists, and for every list...
    for elem in event_descr_items:
        # If there's more than one element (that means, we have description and title)...
        if len(elem) > 1:
            # Then the first element will be the key and the second one will be the value in our new dict
            title_descr[elem[0]] = elem[1]
        # If we don't have two values (we are missing the title)...
        else:
            # Then, the key will be the numerical value we defined and the value will be the only value of the list, which should be the description
            title_descr[no_title_count] = elem[0]
            no_title_count += 1

    return title_descr

#### Function 4
def remove_html(title_descr):
    # This is to remove all the html tags from the text
    for key, value in title_descr.items():
        title_descr[key] = re.sub(r"\<.*?\>", "", value)

    return title_descr
    
#### Function 5
def remove_emojis(string, emoji_list):
    # We'll save all the actual characters (not emojis) here
    new_string = []
    # Iterate over the string
    for s in string:
        # If character not in the emoji list
        if s not in emoji_list:
            # append it to the new_string list
            new_string.append(s)
    
    # join the list into a new string
    return "".join(map(str, new_string))

#### Function 6
def remove_all_emojis(title_descr_without_html, emojis, info_names):
    
    for key, val in title_descr_without_html.items():
        if key in info_names:
            pass
        else:
            title_descr_without_html[key] = remove_emojis(title_descr_without_html[key], emojis)

    return title_descr_without_html

#### Function 7
def separate_info_sections(title_descr_without_html, info_names, icons_list):
    # Now I have to do all the processing with the iterators to pull the information from "Información general".

    # We'll need an iterator
    # iterator = new_dict["Información General"]
    for name in info_names:
        try:
            iterator = title_descr_without_html[name]
            break
        except:
            pass

    # We'll need an empty list too, save the subsections
    general_info_sections = []

    # Iterate over all the icons in the list
    for icon in icons_list:
        # If the icon is in the iterator (string)...
        if icon in iterator:
            # Split iterator using the icon and save it as the new iterator
            # Input: string
            # Output: list with 2 items
            iterator = iterator.split(icon)
            # Save the first item in our new list
            general_info_sections.append(iterator[0])

            # Check if there is still any icon left in the second element of the iterator
            if any(icon in iterator[1] for icon in icons_list):
                # If so, save it as the new iterator (a string again)
                iterator = iterator[1]

            # Else, save it in our new list.
            # As we don't have more icons in the second element, that means, we don't need to split the iterator anymore, since we already reach the last piece of info we needed
            else:
                general_info_sections.append(iterator[1])
        else:
            pass

    return general_info_sections

#### Function 8
def separate_info_sections_title_descr(general_info_sections):
    
    new_general_info_sections = []

    for elem in general_info_sections:
        if len(elem) > 1:
            new_general_info_sections.append(elem.split(":", 1))

    return new_general_info_sections

#### Function 9
def transform_info_sections(new_general_info_sections):
    sections = {}
    extra = 1

    for list_ in new_general_info_sections:
        if len(list_) > 1:
            sections[list_[0]] = list_[1]
        else:
            sections[extra] = list_[0]
            extra += 1

    return sections

#### Function 10
def add_rest(sections, event_title, event_price):
    rest = {"Event_title": event_title, "Event_price": event_price}
    final_dict = {**sections, **rest}
    return final_dict

#### Function 11
def create_df(dict1, dict2, index):
    # Creating dfs
    main_sections_df = pd.DataFrame(dict1, index = [index])
    subsections_df = pd.DataFrame(dict2, index = [index])

    # Joining dfs
    full_df = pd.merge(main_sections_df, subsections_df, how = "outer", left_index = True, right_index = True)

    return full_df

# %%
def processor(source, emojis, section_emojis, info_names, index):
    section, url, image = source

    # Step 1: Get data
    try:
        event_title, event_descr, event_price = get_data(url)
    except:
        return "Step 1 error"

    # Step 2: Split event_descr into sections
    try:
        event_descr_items = separate_sections(event_descr)
    except:
        return "Step 2 error"

    # Step 3: Split sections into titles and descriptions
    try:
        title_descr = separate_title_descr(event_descr_items)
    except:
        return "Step 3 error"

    # Step 4: Some cleaning
    # 4.1 Remove html
    try:
        title_descr_without_html = remove_html(title_descr)
    except:
        return "Step 4.1 error"
    # 4.2 Remove emojis
    try:
        cleaned_dict = remove_all_emojis(title_descr_without_html, emojis, info_names)
    except:
        return "Step 4.2 error"

    # Step 5: Get data from "info" section
    try:
        general_info_sections = separate_info_sections(title_descr_without_html, info_names, section_emojis)
    except:
        return "Step 5 error"
    # 5.1 Split the data from "info" section into title and descr
    try:
        new_general_info_sections = separate_info_sections_title_descr(general_info_sections)
    except:
        return "Step 5.1 error"

    # Step 6: Make the "info" subsections a list
    try:
        info_sections = transform_info_sections(new_general_info_sections)
    except:
        return "Step 6 error"

    # Step 7: Join all the data together into a dict
    try:
        final_dict = add_rest(info_sections, event_title, event_price)
    except:
        return "Step 7 error"

    # Step 8: Create joined dataframe
    try:
        df = create_df(cleaned_dict, final_dict, index)
    except:
        return "Step 8 error"

    # Step 9: Add the event url and image
    try:
        df["url"] = url
        df["image"] = image
        df["event_type"] = section
    except:
        return "Step 9 error"

    return df

# %% [markdown]
# url = "https://feverup.com/m/98148"
# emojis = emoji.UNICODE_EMOJI["en"]
# section_emojis = ["📅", "🕒", "⏳", "👤", "📍", "⚠️", "♿", "⌚", "❓", "🔗"]
# info_names = ["Información", "Información General"]
# index = 0
#
# processor(url, emojis, section_emojis, info_names, index)

# %%
def multiple_processor(sources, emojis, section_emojis, info_names, index):
    dfs = []

    for source_ in sources:
        df_ = processor(source_, emojis, section_emojis, info_names, index)

        if type(df_) != str:
            dfs.append(df_)
            print(index, source_)
        else:
            print(index, source_, df_)
        index += 1
        
    return pd.concat(dfs)

# %%
emojis = emoji.UNICODE_EMOJI["en"]
section_emojis = ["📅", "🕒", "⏳", "👤", "📍", "⚠️", "♿", "⌚", "❓", "🔗"]
info_names = ["Información", "Información General", "Información:", "Información general"]
index = 0

dfs = []

for section in section_urls:
    urls = get_events(section)
    df = multiple_processor(urls, emojis, section_emojis, info_names, index)
    dfs.append(df)
    print("-" * 20, "Section done", "-" * 20)
# Out:
# 0 ('Arte', 'https://feverup.com/m/100122', 'https://fever.imgix.net/plan/photo/0831cb1f-cf6d-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Arte', 'https://feverup.com/m/95287', 'https://fever.imgix.net/plan/photo/e1039d5e-5cc1-11eb-8b1e-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Arte', 'https://feverup.com/m/97759', 'https://fever.imgix.net/plan/photo/8fcd59b1-c3ab-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Arte', 'https://feverup.com/m/96379', 'https://fever.imgix.net/plan/photo/15de4ab8-7d94-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Arte', 'https://feverup.com/m/87806', 'https://fever.imgix.net/plan/photo/71da0628-b6ec-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Arte', 'https://feverup.com/m/94382', 'https://fever.imgix.net/plan/photo/849b65bc-3ed8-11eb-9bdd-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Arte', 'https://feverup.com/m/64894', 'https://fever.imgix.net/plan/photo/d1555670-577b-11e8-8f1d-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Arte', 'https://feverup.com/m/99841', 'https://fever.imgix.net/plan/photo/5e0576af-cd00-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Arte', 'https://feverup.com/m/98148', 'https://fever.imgix.net/plan/photo/2ede03b8-adc1-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Arte', 'https://feverup.com/m/92796', 'https://fever.imgix.net/plan/photo/3ce279ca-146e-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Atracciones', 'https://feverup.com/m/100122', 'https://fever.imgix.net/plan/photo/0831cb1f-cf6d-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Atracciones', 'https://feverup.com/m/99411', 'https://fever.imgix.net/plan/photo/06f1f91a-e959-11eb-8378-b6e037f1d5e5.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Atracciones', 'https://feverup.com/m/97759', 'https://fever.imgix.net/plan/photo/8fcd59b1-c3ab-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Atracciones', 'https://feverup.com/m/96379', 'https://fever.imgix.net/plan/photo/15de4ab8-7d94-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Atracciones', 'https://feverup.com/m/93402', 'https://fever.imgix.net/plan/photo/3ead99a8-28b7-11eb-9bdd-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Atracciones', 'https://feverup.com/m/87806', 'https://fever.imgix.net/plan/photo/71da0628-b6ec-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Atracciones', 'https://feverup.com/m/77966', 'https://fever.imgix.net/plan/photo/e2679a96-bdb5-11e9-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Atracciones', 'https://feverup.com/m/73097', 'https://fever.imgix.net/plan/photo/4d4c221c-af04-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Atracciones', 'https://feverup.com/m/97749', 'https://fever.imgix.net/plan/photo/e9963ce4-a28d-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Atracciones', 'https://feverup.com/m/92137', 'https://fever.imgix.net/plan/photo/8a8f6630-03cf-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Brunch', 'https://feverup.com/m/93216', 'https://fever.imgix.net/plan/photo/202539a9-2373-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Brunch', 'https://feverup.com/m/94444', 'https://fever.imgix.net/plan/photo/5c554317-510c-11eb-8b1e-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Brunch', 'https://feverup.com/m/83769', 'https://fever.imgix.net/plan/photo/92773ed2-4993-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Brunch', 'https://feverup.com/m/88570', 'https://fever.imgix.net/plan/photo/a8d406d7-b153-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Brunch', 'https://feverup.com/m/70275', 'https://fever.imgix.net/plan/photo/4c7c04f3-a964-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Brunch', 'https://feverup.com/m/92243', 'https://fever.imgix.net/plan/photo/2ffb6d3a-04ac-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Brunch', 'https://feverup.com/m/91901', 'https://fever.imgix.net/plan/photo/87de52da-fd77-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Brunch', 'https://feverup.com/m/99447', 'https://fever.imgix.net/plan/photo/1e96e140-c44c-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Brunch', 'https://feverup.com/m/92401', 'https://fever.imgix.net/plan/photo/12e1a886-096b-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Brunch', 'https://feverup.com/m/97637', 'https://fever.imgix.net/plan/photo/2bfed4e5-a12b-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Dinner', 'https://feverup.com/m/97747', 'https://fever.imgix.net/plan/photo/b9b4adac-a28e-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Dinner', 'https://feverup.com/m/97749', 'https://fever.imgix.net/plan/photo/e9963ce4-a28d-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Dinner', 'https://feverup.com/m/97748', 'https://fever.imgix.net/plan/photo/edec14b6-a28e-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Dinner', 'https://feverup.com/m/97750', 'https://fever.imgix.net/plan/photo/14fdb818-a28d-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Terrazas', 'https://feverup.com/m/69706', 'https://fever.imgix.net/plan/photo/15ce6ec2-e115-11e8-a5f5-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Terrazas', 'https://feverup.com/m/93216', 'https://fever.imgix.net/plan/photo/202539a9-2373-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Terrazas', 'https://feverup.com/m/91378', 'https://fever.imgix.net/plan/photo/d53acba8-edbf-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Terrazas', 'https://feverup.com/m/91390', 'https://fever.imgix.net/plan/photo/c4b3a53e-edbc-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Terrazas', 'https://feverup.com/m/69819', 'https://fever.imgix.net/plan/photo/6e9f1eb6-bb84-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Terrazas', 'https://feverup.com/m/91267', 'https://fever.imgix.net/plan/photo/26a33be2-0a3a-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Terrazas', 'https://feverup.com/m/88572', 'https://fever.imgix.net/plan/photo/6095992c-c2ad-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Terrazas', 'https://feverup.com/m/69495', 'https://fever.imgix.net/plan/photo/0c9c37b6-db58-11e8-aed8-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Terrazas', 'https://feverup.com/m/94722', 'https://fever.imgix.net/plan/photo/e94f7cb4-48e9-11eb-8b1e-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Terrazas', 'https://feverup.com/m/94721', 'https://fever.imgix.net/plan/photo/13797ff2-451a-11eb-8b1e-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Deportes', 'https://feverup.com/m/64762', 'https://fever.imgix.net/plan/photo/4274e8e0-52a7-11e8-89fe-067dfd978c4d.png?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Deportes', 'https://feverup.com/m/74440', 'https://fever.imgix.net/plan/photo/fb9da900-547d-11e9-b565-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Deportes', 'https://feverup.com/m/99447', 'https://fever.imgix.net/plan/photo/1e96e140-c44c-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Deportes', 'https://feverup.com/m/99784', 'https://fever.imgix.net/plan/photo/9ba24227-ca99-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Deportes', 'https://feverup.com/m/99205', 'https://fever.imgix.net/plan/photo/1ca4fb0e-c1f6-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Deportes', 'https://feverup.com/m/97009', 'https://fever.imgix.net/plan/photo/e73ce0a6-8d5b-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Deportes', 'https://feverup.com/m/96585', 'https://fever.imgix.net/plan/photo/011e03de-a1bb-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Deportes', 'https://feverup.com/m/91978', 'https://fever.imgix.net/plan/photo/3552862c-ff04-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Deportes', 'https://feverup.com/m/100334', 'https://fever.imgix.net/plan/photo/698a33f2-d348-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Deportes', 'https://feverup.com/m/100351', 'https://fever.imgix.net/plan/photo/e5b4470e-d36d-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Conciertos', 'https://feverup.com/m/97044', 'https://fever.imgix.net/plan/photo/8e69b71e-91fe-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Conciertos', 'https://feverup.com/m/96831', 'https://fever.imgix.net/plan/photo/1211c7ea-87fd-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Conciertos', 'https://feverup.com/m/97053', 'https://fever.imgix.net/plan/photo/0aa036e0-8e1d-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Conciertos', 'https://feverup.com/m/100404', 'https://fever.imgix.net/plan/photo/ffbef88e-d434-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Conciertos', 'https://feverup.com/m/101179', 'https://fever.imgix.net/plan/photo/3070e2ba-e4bd-11eb-b329-cee460cbbb1a.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Conciertos', 'https://feverup.com/m/101265', 'https://fever.imgix.net/plan/photo/8584bc3a-e64e-11eb-86b4-dee5bc6dcc62.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Conciertos', 'https://feverup.com/m/100896', 'https://fever.imgix.net/plan/photo/6ef77030-df18-11eb-b9f7-6a68b27be3f2.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Conciertos', 'https://feverup.com/m/100938', 'https://fever.imgix.net/plan/photo/a0647bf8-dfff-11eb-8172-1223b7202a60.png?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Conciertos', 'https://feverup.com/m/100405', 'https://fever.imgix.net/plan/photo/aa66c2cf-d437-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Conciertos', 'https://feverup.com/m/97280', 'https://fever.imgix.net/plan/photo/32e05ec6-96bc-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Actividades', 'https://feverup.com/m/99005', 'https://fever.imgix.net/plan/photo/0dafb862-ba48-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Actividades', 'https://feverup.com/m/77966', 'https://fever.imgix.net/plan/photo/e2679a96-bdb5-11e9-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Actividades', 'https://feverup.com/m/73097', 'https://fever.imgix.net/plan/photo/4d4c221c-af04-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Actividades', 'https://feverup.com/m/99447', 'https://fever.imgix.net/plan/photo/1e96e140-c44c-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Actividades', 'https://feverup.com/m/97743', 'https://fever.imgix.net/plan/photo/fbe97c84-a27a-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Actividades', 'https://feverup.com/m/99784', 'https://fever.imgix.net/plan/photo/9ba24227-ca99-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Actividades', 'https://feverup.com/m/85952', 'https://fever.imgix.net/plan/photo/43c81440-75d3-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Actividades', 'https://feverup.com/m/68864', 'https://fever.imgix.net/plan/photo/bf8405da-4736-11e9-bb7f-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Actividades', 'https://feverup.com/m/91958', 'https://fever.imgix.net/plan/photo/c2bcade6-fe3d-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720') Step 5 error
# 9 ('Actividades', 'https://feverup.com/m/94375', 'https://fever.imgix.net/plan/photo/232cb650-6d22-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Belleza', 'https://feverup.com/m/99005', 'https://fever.imgix.net/plan/photo/0dafb862-ba48-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Belleza', 'https://feverup.com/m/77966', 'https://fever.imgix.net/plan/photo/e2679a96-bdb5-11e9-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Belleza', 'https://feverup.com/m/73097', 'https://fever.imgix.net/plan/photo/4d4c221c-af04-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Belleza', 'https://feverup.com/m/99447', 'https://fever.imgix.net/plan/photo/1e96e140-c44c-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Belleza', 'https://feverup.com/m/97743', 'https://fever.imgix.net/plan/photo/fbe97c84-a27a-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Belleza', 'https://feverup.com/m/99784', 'https://fever.imgix.net/plan/photo/9ba24227-ca99-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Belleza', 'https://feverup.com/m/85952', 'https://fever.imgix.net/plan/photo/43c81440-75d3-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Belleza', 'https://feverup.com/m/68864', 'https://fever.imgix.net/plan/photo/bf8405da-4736-11e9-bb7f-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Belleza', 'https://feverup.com/m/91958', 'https://fever.imgix.net/plan/photo/c2bcade6-fe3d-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720') Step 5 error
# 9 ('Belleza', 'https://feverup.com/m/94375', 'https://fever.imgix.net/plan/photo/232cb650-6d22-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Afterwork', 'https://feverup.com/m/100103', 'https://fever.imgix.net/plan/photo/16077f1f-cf51-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Afterwork', 'https://feverup.com/m/91251', 'https://fever.imgix.net/plan/photo/a1532106-f273-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Afterwork', 'https://feverup.com/m/99411', 'https://fever.imgix.net/plan/photo/06f1f91a-e959-11eb-8378-b6e037f1d5e5.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Afterwork', 'https://feverup.com/m/91841', 'https://fever.imgix.net/plan/photo/04e56e88-f9a7-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Afterwork', 'https://feverup.com/m/94444', 'https://fever.imgix.net/plan/photo/5c554317-510c-11eb-8b1e-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Afterwork', 'https://feverup.com/m/92223', 'https://fever.imgix.net/plan/photo/544c5a96-0482-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Afterwork', 'https://feverup.com/m/101093', 'https://fever.imgix.net/plan/photo/ecdce7f8-e3cf-11eb-86cb-62bdc7b5ae04.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Afterwork', 'https://feverup.com/m/84341', 'https://fever.imgix.net/plan/photo/0f9f691e-6086-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Afterwork', 'https://feverup.com/m/93390', 'https://fever.imgix.net/plan/photo/0ded707e-27fc-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Afterwork', 'https://feverup.com/m/100901', 'https://fever.imgix.net/plan/photo/bda83bb8-dfd8-11eb-9609-a2dcff75d2dd.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Clubs', 'https://feverup.com/m/94492', 'https://fever.imgix.net/plan/photo/825d43ba-3fc8-11eb-8b1e-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Clubs', 'https://feverup.com/m/100103', 'https://fever.imgix.net/plan/photo/16077f1f-cf51-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Clubs', 'https://feverup.com/m/100978', 'https://fever.imgix.net/plan/photo/e92ee03e-e0b9-11eb-8150-ea8826e351c1.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Clubs', 'https://feverup.com/m/100603', 'https://fever.imgix.net/plan/photo/f8fd65a6-d8e1-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Clubs', 'https://feverup.com/m/100497', 'https://fever.imgix.net/plan/photo/a8043fd4-d5a6-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Clubs', 'https://feverup.com/m/101093', 'https://fever.imgix.net/plan/photo/ecdce7f8-e3cf-11eb-86cb-62bdc7b5ae04.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Clubs', 'https://feverup.com/m/100901', 'https://fever.imgix.net/plan/photo/bda83bb8-dfd8-11eb-9609-a2dcff75d2dd.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Clubs', 'https://feverup.com/m/91959', 'https://fever.imgix.net/plan/photo/8695a500-ff3e-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Clubs', 'https://feverup.com/m/101082', 'https://fever.imgix.net/plan/photo/7e70699a-e3eb-11eb-807f-3e037c7ac9b8.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Clubs', 'https://feverup.com/m/100811', 'https://fever.imgix.net/plan/photo/4af58626-dd93-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Aire_libre', 'https://feverup.com/m/91978', 'https://fever.imgix.net/plan/photo/3552862c-ff04-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Aire_libre', 'https://feverup.com/m/100936', 'https://fever.imgix.net/plan/photo/c372d400-e004-11eb-bc84-4e4e4dc731a5.png?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Aire_libre', 'https://feverup.com/m/100044', 'https://fever.imgix.net/plan/photo/91820008-d59e-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Aire_libre', 'https://feverup.com/m/100978', 'https://fever.imgix.net/plan/photo/e92ee03e-e0b9-11eb-8150-ea8826e351c1.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Aire_libre', 'https://feverup.com/m/100603', 'https://fever.imgix.net/plan/photo/f8fd65a6-d8e1-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Aire_libre', 'https://feverup.com/m/100497', 'https://fever.imgix.net/plan/photo/a8043fd4-d5a6-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Aire_libre', 'https://feverup.com/m/99411', 'https://fever.imgix.net/plan/photo/06f1f91a-e959-11eb-8378-b6e037f1d5e5.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Aire_libre', 'https://feverup.com/m/98656', 'https://fever.imgix.net/plan/photo/ae767a64-af4b-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Aire_libre', 'https://feverup.com/m/93402', 'https://fever.imgix.net/plan/photo/3ead99a8-28b7-11eb-9bdd-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Aire_libre', 'https://feverup.com/m/74440', 'https://fever.imgix.net/plan/photo/fb9da900-547d-11e9-b565-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Candlelights', 'https://feverup.com/m/96831', 'https://fever.imgix.net/plan/photo/1211c7ea-87fd-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Candlelights', 'https://feverup.com/m/97053', 'https://fever.imgix.net/plan/photo/0aa036e0-8e1d-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Candlelights', 'https://feverup.com/m/78547', 'https://fever.imgix.net/plan/photo/9ed1c8e4-5b35-11eb-8b1e-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720') Step 5 error
# 3 ('Candlelights', 'https://feverup.com/m/100404', 'https://fever.imgix.net/plan/photo/ffbef88e-d434-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Candlelights', 'https://feverup.com/m/100896', 'https://fever.imgix.net/plan/photo/6ef77030-df18-11eb-b9f7-6a68b27be3f2.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Candlelights', 'https://feverup.com/m/100405', 'https://fever.imgix.net/plan/photo/aa66c2cf-d437-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Candlelights', 'https://feverup.com/m/97280', 'https://fever.imgix.net/plan/photo/32e05ec6-96bc-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Candlelights', 'https://feverup.com/m/98160', 'https://fever.imgix.net/plan/photo/8e120dda-adaf-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Candlelights', 'https://feverup.com/m/100980', 'https://fever.imgix.net/plan/photo/c9403492-e0c0-11eb-a5a2-f29321d0df9f.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Candlelights', 'https://feverup.com/m/84521', 'https://fever.imgix.net/plan/photo/629c34a6-c217-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Tributos', 'https://feverup.com/m/100938', 'https://fever.imgix.net/plan/photo/a0647bf8-dfff-11eb-8172-1223b7202a60.png?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Tributos', 'https://feverup.com/m/100892', 'https://fever.imgix.net/plan/photo/9300ebfe-e09f-11eb-8694-92021077a359.png?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Tributos', 'https://feverup.com/m/100936', 'https://fever.imgix.net/plan/photo/c372d400-e004-11eb-bc84-4e4e4dc731a5.png?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Tributos', 'https://feverup.com/m/100939', 'https://fever.imgix.net/plan/photo/9a4788f0-e004-11eb-b4e4-6e56c70bc415.png?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Gastronomía', 'https://feverup.com/m/100044', 'https://fever.imgix.net/plan/photo/91820008-d59e-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Gastronomía', 'https://feverup.com/m/100103', 'https://fever.imgix.net/plan/photo/16077f1f-cf51-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('Gastronomía', 'https://feverup.com/m/83073', 'https://fever.imgix.net/plan/photo/1e591886-3bb0-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Gastronomía', 'https://feverup.com/m/95510', 'https://fever.imgix.net/plan/photo/6041a17c-655b-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('Gastronomía', 'https://feverup.com/m/97841', 'https://fever.imgix.net/plan/photo/7c13c550-a428-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Gastronomía', 'https://feverup.com/m/64531', 'https://fever.imgix.net/plan/photo/1d73face-5395-11e8-9270-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Gastronomía', 'https://feverup.com/m/70275', 'https://fever.imgix.net/plan/photo/4c7c04f3-a964-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Gastronomía', 'https://feverup.com/m/93216', 'https://fever.imgix.net/plan/photo/202539a9-2373-11eb-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Gastronomía', 'https://feverup.com/m/74168', 'https://fever.imgix.net/plan/photo/6a9fbff0-4f15-11e9-9a0b-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Gastronomía', 'https://feverup.com/m/69982', 'https://fever.imgix.net/plan/photo/1f052430-e80f-11e8-a7f4-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Cine', 'https://feverup.com/m/100717', 'https://fever.imgix.net/plan/photo/0349a67e-da62-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Cine', 'https://feverup.com/m/95555', 'https://fever.imgix.net/plan/photo/d3c8009c-6632-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720') Step 5 error
# 2 ('Cine', 'https://feverup.com/m/100984', 'https://fever.imgix.net/plan/photo/120ae790-e0c5-11eb-ab6b-728d1167d699.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Cine', 'https://feverup.com/m/54872', 'https://fever.imgix.net/plan/photo/fc61fc8c-81ae-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720') Step 5 error
# 4 ('Cine', 'https://feverup.com/m/84521', 'https://fever.imgix.net/plan/photo/629c34a6-c217-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Cine', 'https://feverup.com/m/100715', 'https://fever.imgix.net/plan/photo/29bd8ffe-da63-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Cine', 'https://feverup.com/m/101158', 'https://fever.imgix.net/plan/photo/9dacff16-e49b-11eb-8bd9-56e076431432.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Cine', 'https://feverup.com/m/100893', 'https://fever.imgix.net/plan/photo/9f34525a-df12-11eb-965c-6a68b27be3f2.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Cine', 'https://feverup.com/m/100690', 'https://fever.imgix.net/plan/photo/ff31780e-da49-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Cine', 'https://feverup.com/m/101160', 'https://fever.imgix.net/plan/photo/eba7255c-e49b-11eb-85c2-b668a691c73c.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------
# 0 ('Teatro', 'https://feverup.com/m/70448', 'https://fever.imgix.net/plan/photo/05fa789c-f3e4-11e8-91ba-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('Teatro', 'https://feverup.com/m/70951', 'https://fever.imgix.net/plan/photo/c836fe18-0211-11e9-a7b6-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720') Step 5 error
# 2 ('Teatro', 'https://feverup.com/m/99000', 'https://fever.imgix.net/plan/photo/fd2679d2-ba1f-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('Teatro', 'https://feverup.com/m/70445', 'https://fever.imgix.net/plan/photo/e70358f6-f49b-11e8-a712-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720') Step 5 error
# 4 ('Teatro', 'https://feverup.com/m/95234', 'https://fever.imgix.net/plan/photo/43770eaa-6228-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('Teatro', 'https://feverup.com/m/88298', 'https://fever.imgix.net/plan/photo/5486f4a8-afe6-11ea-bf03-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('Teatro', 'https://feverup.com/m/73446', 'https://fever.imgix.net/plan/photo/3fe3b770-3c33-11e9-b577-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('Teatro', 'https://feverup.com/m/98148', 'https://fever.imgix.net/plan/photo/2ede03b8-adc1-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('Teatro', 'https://feverup.com/m/65271', 'https://fever.imgix.net/plan/photo/6abf33e4-6316-11e8-81fa-067dfd978c4d.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('Teatro', 'https://feverup.com/m/94432', 'https://fever.imgix.net/plan/photo/d2331cd6-3ee2-11eb-9bdd-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# -------------------- Section done --------------------

# %%
for column in dfs[1].columns: print(column)
# Out:
# 1_x
# Tickets
# Qué vas a disfrutar
# Información General
# Descripción
#  Fechas
#  Horarios
#  Duración
#  Edad
#  Lugar
#  Accesibilidad
# 1_y
# Event_title
# Event_price
# url
# image
# Información
# Valoraciones
# 1
# Valoraciones de usuarios
# 🕐 Fecha y hora
#  Fecha y hora
# Cosas alucinantes que disfrutarás
# Información general
# 📍 Lugar
#  Información importante
#  Horarios de abril
#  Podrás canjear tu bono durante el periodo de un año tras su compra🎁 Beneficio Fever
#  Horarios de inicio

# %% [markdown]
# # Candlelights

# %%
#candlelight_urls = ['https://feverup.com/m/96831', 'https://feverup.com/m/97975', 'https://feverup.com/m/97053', 'https://feverup.com/m/100404', 'https://feverup.com/m/100896', 'https://feverup.com/m/95040', 'https://feverup.com/m/100405', 'https://feverup.com/m/98160', 'https://feverup.com/m/97280', 'https://feverup.com/m/84521']
candlelight = [('https://feverup.com/m/84521',
  'https://fever.imgix.net/plan/photo/629c34a6-c217-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/96831',
  'https://fever.imgix.net/plan/photo/1211c7ea-87fd-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/97053',
  'https://fever.imgix.net/plan/photo/0aa036e0-8e1d-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/100404',
  'https://fever.imgix.net/plan/photo/ffbef88e-d434-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/100896',
  'https://fever.imgix.net/plan/photo/6ef77030-df18-11eb-b9f7-6a68b27be3f2.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/100405',
  'https://fever.imgix.net/plan/photo/aa66c2cf-d437-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/97280',
  'https://fever.imgix.net/plan/photo/32e05ec6-96bc-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/98160',
  'https://fever.imgix.net/plan/photo/8e120dda-adaf-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/100980',
  'https://fever.imgix.net/plan/photo/c9403492-e0c0-11eb-a5a2-f29321d0df9f.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720'),
 ('https://feverup.com/m/97975',
  'https://fever.imgix.net/plan/photo/8268fa5a-a73a-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')]

emojis = emoji.UNICODE_EMOJI["en"]
section_emojis = ["📅", "🕒", "⏳", "👤", "📍", "⚠️", "♿", "⌚", "❓", "🔗"]
info_names = ["Información", "Información General", "Información:", "Información general"]
index = 0

df_1 = multiple_processor(candlelight, emojis, section_emojis, info_names, index)
# Out:
# 0 ('https://feverup.com/m/84521', 'https://fever.imgix.net/plan/photo/629c34a6-c217-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 1 ('https://feverup.com/m/96831', 'https://fever.imgix.net/plan/photo/1211c7ea-87fd-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 2 ('https://feverup.com/m/97053', 'https://fever.imgix.net/plan/photo/0aa036e0-8e1d-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 3 ('https://feverup.com/m/100404', 'https://fever.imgix.net/plan/photo/ffbef88e-d434-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 4 ('https://feverup.com/m/100896', 'https://fever.imgix.net/plan/photo/6ef77030-df18-11eb-b9f7-6a68b27be3f2.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 5 ('https://feverup.com/m/100405', 'https://fever.imgix.net/plan/photo/aa66c2cf-d437-11eb-9522-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 6 ('https://feverup.com/m/97280', 'https://fever.imgix.net/plan/photo/32e05ec6-96bc-11eb-b783-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 7 ('https://feverup.com/m/98160', 'https://fever.imgix.net/plan/photo/8e120dda-adaf-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 8 ('https://feverup.com/m/100980', 'https://fever.imgix.net/plan/photo/c9403492-e0c0-11eb-a5a2-f29321d0df9f.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')
# 9 ('https://feverup.com/m/97975', 'https://fever.imgix.net/plan/photo/8268fa5a-a73a-11eb-9520-06551cb39bc6.jpg?auto=compress&auto=format&fm=jpg&w=720&h=720')

# %%
# 1) Generate full candlelights dataframe
candlelights_df = df_1

# 2) Let's start filling NaNs and combining columns
# NaN filling
candlelights_df.loc[:, ["Intérprete:", "Intérpretes:"]] = candlelights_df.loc[:, ["Intérprete:", "Intérpretes:"]].fillna("")
candlelights_df.loc[:, ["Información:", "Información general"]] = candlelights_df.loc[:, ["Información:", "Información general"]].fillna("")
candlelights_df.loc[:, [" Duración aproximada", " Duración del concierto", " Duración"]] = candlelights_df.loc[:, [" Duración aproximada", " Duración del concierto", " Duración"]].fillna("")
candlelights_df.loc[:, ["Valoraciones de otros usuarios", "Valoraciones de usuarios de otros conciertos Candlelight"]] = candlelights_df.loc[:, ["Valoraciones de otros usuarios", "Valoraciones de usuarios de otros conciertos Candlelight"]].fillna("")

# Columns combination
candlelights_df["Interprete"] = candlelights_df["Intérprete:"].astype(str) + candlelights_df["Intérpretes:"].astype(str)
#candlelights_df["Informacion"] = candlelights_df["Información:"].astype(str) + candlelights_df["Información general"].astype(str)
candlelights_df["Duracion"] = candlelights_df[" Duración aproximada"].astype(str) + candlelights_df[" Duración del concierto"].astype(str) + candlelights_df[" Duración"].astype(str)
candlelights_df["Valoraciones"] = candlelights_df["Valoraciones de otros usuarios"].astype(str) + candlelights_df["Valoraciones de usuarios de otros conciertos Candlelight"].astype(str)

# 3) Drop columns
candlelights_df = candlelights_df.drop(["Intérprete:", "Intérpretes:", "Información:", "Información general", "El uso de la mascarilla es obligatorio durante el conciertoPrograma", " La seguridad de nuestros asistentes es una prioridad para Fever. Puedes consultar las medidas de seguridad de este evento aquíPrograma", "El uso de la mascarilla es obligatorio durante el conciertoPrograma", 1, "1_x", "1_y", 2, " Duración aproximada", " Duración del concierto", " Duración", "Valoraciones de otros usuarios", "Valoraciones de usuarios de otros conciertos Candlelight"], axis = 1)
candlelights_df = candlelights_df.rename({"📍 Lugar" : "Lugar"}, axis = 1)

print(candlelights_df.shape)
candlelights_df
# Out:
# (10, 15)
#                                              Tickets  \
# 0   Entrada zona A: mejor visibilidad Entrada zon...
# 1   Entrada zona A: muy buena visibilidad Entrada...
# 2   Entrada zona A: mejor visibilidad Entrada zon...
# 3   Entrada zona A: muy buena visibilidad Entrada...
# 4   Entrada zona A: mejor visibilidad Entrada zon...
# 5   Entrada zona A: mejor visibilidad Entrada zon...
# 6   Entrada zona A: muy buena visibilidad Entrada...
# 7   Entrada zona A: mejor visibilidad Entrada zon...
# 8   Entrada zona A: mejor visibilidad Entrada zon...
# 9   Entrada zona A: muy buena visibilidad Entrada...
#
#                                  Qué vas a disfrutar  \
# 0  ️ Una atmósfera muy íntima en una espectacular...
# 1  ️ Una atmósfera muy íntima en una localización...
# 2  ️ Una atmósfera muy íntima en una espectacular...
# 3  ️ Una atmósfera muy íntima en una espectacular...
# 4  ️ Una atmósfera muy íntima en una espectacular...
# 5  ️ Una atmósfera muy íntima en una espectacular...
# 6  ️ Una atmósfera muy íntima en una espectacular...
# 7  ️ Una atmósfera muy íntima en una espectacular...
# 8  ️ Una atmósfera muy íntima en una espectacular...
# 9  ️ Una atmósfera muy íntima en una espectacular...
#
#                                          Descripción  \
# 0  ¡Disfruta de las mejores bandas sonoras del ci...
# 1  ¡Las mejores canciones de tu infancia, como nu...
# 2  ¡Los mejores temas de Daft Punk, bajo la luz d...
# 3  ¡Disfruta de música clásica como nunca antes e...
# 4  ¡Revive a las leyendas del jazz a la luz de la...
# 5  ¡Disfruta de las mejores bandas sonoras del ci...
# 6  Siente la fuerza y emoción de las voces lírica...
# 7  ¡Las Cuatro Estaciones de Vivaldi, como nunca ...
# 8  ¡Homenaje a Paco de Lucía bajo la luz de las v...
# 9  ¡Mozart, como nunca antes! Vive una experienci...
#
#                                       Lugar  \
# 0                               Teatro Goya
# 1                               Teatro Goya
# 2                  El Capricho, Teatro Goya
# 3    Círculo de Bellas Artes, Sala Columnas
# 4                               Teatro Goya
# 5   Círculo de Bellas Artes - Sala Columnas
# 6   Círculo de Bellas Artes - Sala Columnas
# 7   Círculo de Bellas Artes - Sala Columnas
# 8                               Teatro Goya
# 9   Círculo de Bellas Artes - Sala Columnas
#
#                                         Fecha y hora  \
# 0                        varias opciones a las 21:30
# 1                            7 de agosto a las 21:30
# 2                           28 de agosto a las 21:30
# 3   9, 11, 17 o 19 de septiembre a las 19:00 o la...
# 4                            6 de agosto a las 21:30
# 5           10 de septiembre a las 19:00 y las 21:00
# 6           18 de septiembre a las 19:00 y las 21:00
# 7   2 de julio y 3 de septiembre a las 19:00 y 21:00
# 8                           22 de agosto a las 21:30
# 9            4 de septiembre a las 19:00 o las 21:00
#
#                                                 Edad  \
# 0   a partir de 8 años. Los menores de 16 años de...
# 1   a partir de 8 años. Los menores de 16 años de...
# 2   a partir de 8 años. Los menores de 16 años de...
# 3   a partir de 8 años. Los menores de 16 años de...
# 4   a partir de 8 años. Los menores de 16 años de...
# 5   a partir de 8 años. Los menores de 16 años de...
# 6   a partir de 8 años. Los menores de 16 años de...
# 7   a partir de 8 años. Los menores de 16 años de...
# 8   a partir de 8 años. Los menores de 16 años de...
# 9   a partir de 8 años. Los menores de 16 años de...
#
#                                        Accesibilidad  \
# 0   recinto habilitado para personas en silla de ...
# 1   recinto habilitado para personas en silla de ...
# 2   recinto habilitado para personas en silla de ...
# 3   recinto habilitado para personas en silla de ...
# 4   recinto habilitado para personas en silla de ...
# 5   recinto habilitado para personas en silla de ...
# 6   recinto habilitado para personas en silla de ...
# 7   recinto habilitado para personas en silla de ...
# 8   recinto habilitado para personas en silla de ...
# 9   recinto habilitado para personas en silla de ...
#
#                                          Event_title Event_price  \
# 0   Candlelight Open Air: Morricone y otras banda...       25,00
# 1      Candlelight Open Air: Bandas Sonoras Mágicas        15,00
# 2   Candlelight Open Air: Tributo a Daft Punk a l...       25,00
# 3   Candlelight: El Cascanueces y ballet a la luz...       15,00
# 4   Candlelight Jazz Open Air: Tributo a Nina Sim...       25,00
# 5   Candlelight: Bandas Sonoras, cuarteto de cuer...       15,00
# 6   Candlelight: Verdi, La Traviata bajo la luz d...       17,00
# 7   Candlelight: Las cuatro estaciones de Vivaldi...       15,00
# 8   Candlelight Open Air: Homenaje a Paco de Lucí...       15,00
# 9   Candlelight: Réquiem de Mozart a la luz de la...       15,00
#
#                             url  \
# 0   https://feverup.com/m/84521
# 1   https://feverup.com/m/96831
# 2   https://feverup.com/m/97053
# 3  https://feverup.com/m/100404
# 4  https://feverup.com/m/100896
# 5  https://feverup.com/m/100405
# 6   https://feverup.com/m/97280
# 7   https://feverup.com/m/98160
# 8  https://feverup.com/m/100980
# 9   https://feverup.com/m/97975
#
#                                                image  \
# 0  https://fever.imgix.net/plan/photo/629c34a6-c2...
# 1  https://fever.imgix.net/plan/photo/1211c7ea-87...
# 2  https://fever.imgix.net/plan/photo/0aa036e0-8e...
# 3  https://fever.imgix.net/plan/photo/ffbef88e-d4...
# 4  https://fever.imgix.net/plan/photo/6ef77030-df...
# 5  https://fever.imgix.net/plan/photo/aa66c2cf-d4...
# 6  https://fever.imgix.net/plan/photo/32e05ec6-96...
# 7  https://fever.imgix.net/plan/photo/8e120dda-ad...
# 8  https://fever.imgix.net/plan/photo/c9403492-e0...
# 9  https://fever.imgix.net/plan/photo/8268fa5a-a7...
#
#                                             Programa  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  El Lago de los Cisnes, TchaikovskySuite del Ca...
# 4                                                NaN
# 5  Indiana Jones de J. WilliamsCinema Paradiso de...
# 6  Melólogo sobre el preludio"Flora, Amici… si, s...
# 7  1. Primavera (Allegro, Largo, Allegro Pastoral...
# 8  Entre dos aguasAlmorahimaGuajirasConcierto de ...
# 9                                                NaN
#
#                                           Interprete  \
# 0                       Cuarteto de cuerda - Matrice
# 1
# 2  Piano y violín eléctrico - Laura Andrés y Rose...
# 3                       Cuarteto de cuerda - Matrice
# 4  Contrabajo: Sergio FernándezBatería: Martin Da...
# 5                       Cuarteto de cuerda - Matrice
# 6  Pianoforte – tbcVoces- Fausta Ciceroni (sopran...
# 7                       Cuarteto de cuerda - Matrice
# 8                   2 guitarras españolas y un cajón
# 9                       Cuarteto de cuerda - Matrice
#
#                                             Duracion  \
# 0   65 minutos aprox. (apertura de puertas 60 min...
# 1   60 minutos (apertura de puertas 60 minutos an...
# 2   60 minutos aprox. (apertura de puertas 60 min...
# 3   70 minutos aprox. (apertura de puertas 45 min...
# 4   60 minutos aprox. (apertura de puertas 60 min...
# 5   60 minutos aprox. (apertura de puertas 45 min...
# 6   60 minutos aprox. (apertura de puertas 45 min...
# 7   60 minutos aprox. (apertura de puertas 45 min...
# 8   60 minutos aprox. (apertura de puertas 45 min...
# 9   60 minutos aprox. (apertura de puertas 45 min...
#
#                                         Valoraciones
# 0   Clarines V. : "La elección de bandas sonoras ...
# 1   Dre S. : "Muy buena idea y excelente conciert...
# 2   Clara S. : "Todo fantástico. Organización y m...
# 3   Raquel H. : "Precioso, romántico e íntimo. Un...
# 4   Sofía A. : "Una atmósfera muy acogedora y mús...
# 5   Sofía A. : "Una atmósfera muy acogedora, y un...
# 6   Joana B. : "Muy bonito, me emocionó mucho y l...
# 7   Sofía A. : "Una atmósfera muy acogedora, y un...
# 8   Mario P. : "Asombrosas interpretaciones en un...
# 9   Gabriel H. : "Un entorno muy acogedor y prote...

# %%
candlelights_df.to_excel("Candlelights.xlsx")

# %% [markdown]
# # Art events

# %%
art_urls = ['https://feverup.com/m/97759', 'https://feverup.com/m/87806', 'https://feverup.com/m/92796',
             'https://feverup.com/m/92640', 'https://feverup.com/m/96367', 'https://feverup.com/m/94382',
             'https://feverup.com/m/92141']

emojis = emoji.UNICODE_EMOJI["en"]
section_emojis = ["📅", "🕒", "⏳", "👤", "📍", "⚠️", "♿", "⌚", "❓", "🔗"]
info_names = ["Información", "Información General", "Información:", "Información general"]
index = 0

df_2 = multiple_processor(art_urls, emojis, section_emojis, info_names, index)
print(df_2.shape)
# Out:
# 0 https://feverup.com/m/97759
# 1 https://feverup.com/m/87806
# 2 https://feverup.com/m/92796
# 3 https://feverup.com/m/92640
# 4 https://feverup.com/m/96367
# 5 https://feverup.com/m/94382
# 6 https://feverup.com/m/92141
# (7, 28)

# %%
art_df = df_2

# 2) Let's start filling NaNs and combining columns
# NaN filling
art_df.loc[:, ["📍 Lugar", "📌 Lugar", " Lugar"]] = art_df.loc[:, ["📍 Lugar", "📌 Lugar", " Lugar"]].fillna("")
art_df.loc[:, ["Qué vas a disfrutar", "Cosas alucinantes que disfrutarás"]] = art_df.loc[:, ["Qué vas a disfrutar", "Cosas alucinantes que disfrutarás"]].fillna("")
art_df.loc[:, ["Valoraciones de usuarios", "Valoraciones", "Valoraciones sobre el trabajo de Pablo Raijenstein"]] = art_df.loc[:, ["Valoraciones de usuarios", "Valoraciones", "Valoraciones sobre el trabajo de Pablo Raijenstein"]].fillna("")
art_df.loc[:, [" Edad mínima", " Edad"]] = art_df.loc[:, [" Edad mínima", " Edad"]].fillna("")
art_df.loc[:, [" Duración aproximada del recorrido", " Duración"]] = art_df.loc[:, [" Duración aproximada del recorrido", " Duración"]].fillna("")

# Columns combination
art_df["Lugar"] = art_df["📍 Lugar"].astype(str) + art_df["📌 Lugar"].astype(str) + art_df[" Lugar"].astype(str)
art_df["Que vas a disfrutar"] = art_df["Qué vas a disfrutar"].astype(str) + art_df["Qué vas a disfrutar"].astype(str) + art_df["Cosas alucinantes que disfrutarás"].astype(str)
art_df["Valoraciones"] = art_df["Valoraciones de usuarios"].astype(str) + art_df["Valoraciones"].astype(str) + art_df["Valoraciones sobre el trabajo de Pablo Raijenstein"].astype(str)
art_df["Edad"] = art_df[" Edad mínima"].astype(str) + art_df[" Edad"].astype(str)
art_df["Duracion"] = art_df[" Duración aproximada del recorrido"].astype(str) + art_df[" Duración"].astype(str)

# 3) Drop columns
art_df = art_df.drop([1, "📍 Lugar", "📌 Lugar", " Lugar", "Qué vas a disfrutar",
                     "Cosas alucinantes que disfrutarás", "Valoraciones de usuarios",
                     "Valoraciones sobre el trabajo de Pablo Raijenstein", "1_x", "1_y",
                     "🕐 Fecha y hora", " Fechas", " Horarios", "Agatha Ruiz de la Prada u Okuda San Miguel",
                     " Edad mínima", " Edad", " Duración aproximada del recorrido", " Duración",
                     "Información", "Información general"], axis = 1)

art_df = art_df.fillna("")
art_df = art_df[art_df.loc[:, " Accesibilidad"] != ""]

art_df = art_df.drop(["Valoraciones", "Que vas a disfrutar", "Edad", "Duracion"], axis = 1)
print(art_df.shape)
art_df
# Out:
# (1, 8)
#                                              Tickets  \
# 5   Entrada adulto (de 17 a 60 años) Entrada seni...
#
#                                          Descripción  \
# 5  El Museo Lázaro Galdiano es el resultado del l...
#
#                                 Event_title Event_price  Fecha y hora  \
# 5   Entradas para el Museo Lázaro Galdiano         4,50
#
#                               Información importante  \
# 5   existencia de medidas de seguridad debidas al...
#
#                     Accesibilidad  \
# 5   accesible con silla de ruedas
#
#                                                Lugar
# 5   Museo Lázaro Galdiano⌛ Duración aproximada de...

# %%
art_df.to_excel("Art_events.xlsx")

# %% [markdown]
# # Outdoor plans

# %%
outdoor_urls = ['https://feverup.com/m/100044', 'https://feverup.com/m/100978', 
                'https://feverup.com/m/100603', 'https://feverup.com/m/100497',
                'https://feverup.com/m/99411', 'https://feverup.com/m/100896',
                'https://feverup.com/m/74440', 'https://feverup.com/m/98057',
                'https://feverup.com/m/93402', 'https://feverup.com/m/80284']

emojis = emoji.UNICODE_EMOJI["en"]
section_emojis = ["📅", "🕒", "⏳", "👤", "📍", "⚠️", "♿", "⌚", "❓", "🔗"]
info_names = ["Información", "Información General", "Información:", "Información general"]
index = 0

df_3 = multiple_processor(outdoor_urls, emojis, section_emojis, info_names, index)
print(df_3.shape)
# Out:
# 0 https://feverup.com/m/100044
# 1 https://feverup.com/m/100978
# 2 https://feverup.com/m/100603
# 3 https://feverup.com/m/100497
# 4 https://feverup.com/m/99411
# 5 https://feverup.com/m/100896
# 6 https://feverup.com/m/74440
# 7 https://feverup.com/m/98057
# 8 https://feverup.com/m/93402
# 9 https://feverup.com/m/80284
# (10, 31)

# %%
df_3
# Out:
#    1_x                                            Tickets  \
# 0        Entrada Adulto para 1 día completo o media jo...
# 1        Entrada general + 2 consumiciones hasta las 2...
# 2        Entrada general + 2 consumiciones hasta las 2...
# 3        Entrada general + 2 consumiciones hasta las 2...
# 4        Acceso a Corona Paradise, una experiencia sen...
# 5        Entrada zona A: mejor visibilidad Entrada zon...
# 6  NaN   Ruta a caballo para 1 persona de 60, 90 o 120...
# 7  NaN   Kit Bisolé + tabla de madera + bolsa de tela ...
# 8  NaN   Ruta guiada Madrid Encantado para 1 adulto (a...
# 9  NaN   Night Tour de 2 horas por Madrid conduciendo ...
#
#                                  Qué vas a disfrutar  \
# 0   Un refrescante chapuzón en la enorme piscina ...
# 1   Una fiesta en la Terraza de la discoteca más ...
# 2   Una fiesta Remember increíble en la discoteca...
# 3   La vuelta de la fiesta hardstyle de referenci...
# 4   Coge tu mochila y prepara tu cámara porque… ¡...
# 5  ️ Una atmósfera muy íntima en una espectacular...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                          Información  \
# 0  📅 Fecha: todos los días🕒 Horarios:  Entrada dí...
# 1  📅 Fecha: sábado 7 de agosto🕒 Horario: de 19:30...
# 2  📅 Fecha: sábado 24 de julio🕒 Horario: de 19:30...
# 3  📅 Fecha: sábado 31 de julio🕒 Horario: de las 1...
# 4  📅 Fechas: del 1 de julio al 1 de agosto🕒 Horar...
# 5                                                NaN
# 6                                                NaN
# 7  🕐 Fecha de envío:Los envíos solicitados antes ...
# 8  🕒 Fecha y hora: escoge la opción que prefieras...
# 9  🕒 Fecha: escoge la opción que quieras al compr...
#
#                                          Descripción  \
# 0  ¡Comienza la temporada de piscina Club de Tiro...
# 1   ¡Vete preparando porque el sábado 7 de agosto...
# 2  Esperamos que estés descansando bien, porque e...
# 3  Una de tus fiestas de referencia aterriza de n...
# 4   Llega a Madrid la experiencia más divertida y...
# 5  ¡Revive a las leyendas del jazz a la luz de la...
# 6  ¡Siente el aire puro de la sierra a lomos de u...
# 7  ¡Disfruta de los mejores aperitivos gourmet en...
# 8   Conocer Madrid durante la noche es una de las...
# 9  Descubre los lugares más míticos de Madrid des...
#
#                       Valoraciones de otros usuarios  \
# 0   Marta H. : Piscina limpia, césped cuidado, pe...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5   Sofía A. : "Una atmósfera muy acogedora y mús...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                                Fecha  \
# 0                                     todos los días
# 1                                 sábado 7 de agosto
# 2                                 sábado 24 de julio
# 3                                 sábado 31 de julio
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9   escoge la opción que quieras al comprar📍 Luga...
#
#                                             Horarios  \
# 0    Entrada día completo: de 11:00 a 20:30 Entra...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4   varias opciones disponibles📍 Lugar: Palacio d...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                                Lugar  \
# 0   Club de Tiro de El Pardo🚗 Parking exclusivo p...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7   tu casa📱 Encontrarás más detalles sobre tu re...
# 8                                                NaN
# 9                                                NaN
#
#                                                  1_y  ...  \
# 0  No está permitido introducir comida o bebida a...  ...
# 1   Es obligatorio el uso de mascarilla en todo m...  ...
# 2   Es obligatorio el uso de mascarilla en todo m...  ...
# 3   Es obligatorio el uso de mascarilla en todo m...  ...
# 4    La seguridad de nuestros asistentes es una p...  ...
# 5  El uso de la mascarilla es obligatorio durante...  ...
# 6                                                NaN  ...
# 7                                                NaN  ...
# 8                                                NaN  ...
# 9                                                NaN  ...
#
#                                         Fecha y hora  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                            6 de agosto a las 21:30
# 6   sábados y domingos excepto del 1 al 25 de ago...
# 7                                                NaN
# 8   escoge la opción que prefieras al comprar⌚ Du...
# 9                                                NaN
#
#                                             Duración    1  \
# 0                                                NaN  NaN
# 1                                                NaN  NaN
# 2                                                NaN  NaN
# 3                                                NaN  NaN
# 4                                                NaN  NaN
# 5   60 minutos aprox. (apertura de puertas 60 min...  NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                  Información general         Edad mínima  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
# 5                                                NaN                 NaN
# 6  🕒 Fecha y hora: sábados y domingos excepto del...   mayores de 4 años
# 7                                                NaN                 NaN
# 8                                                NaN                 NaN
# 9                                                NaN                 NaN
#
#                                 Información de envío  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7   La distribución está disponible en todo el te...
# 8                                                NaN
# 9                                                NaN
#
#                                           Kit Bisolé  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Aperitivos:Un bote de aceitunas partidas verde...
# 8                                                NaN
# 9                                                NaN
#
#                                       Kit Menorquín:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Aperitivos:Una bolsa de patatas fritas (140 g)...
# 8                                                NaN
# 9                                                NaN
#
#                                     🕐 Fecha de envío  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Los envíos solicitados antes de las 17:00 de l...
# 8                                                NaN
# 9                                                NaN
#
#    Se deberá abonar una fianza que será devuelta a la entrega del vehículo tras la experienciaRutas
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Night Tour: el Madrid más castizo, bajo la luz...
#
# [10 rows x 31 columns]
