# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv("data/IMDb movies.csv")
movies.sample(10)
# Out:
# C:\Users\jgnsa\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       imdb_title_id                              title  \
# 47965     tt0465499              Hoshi ni natta shônen
# 40278     tt0286106                              Signs
# 37918     tt0244452                   Campfire Stories
# 69234     tt2950236                         The Living
# 24045     tt0095559      El Lute II: mañana seré libre
# 57431     tt1371117                      Dear Mr. Gacy
# 57281     tt1352824    Chloe - Tra seduzione e inganno
# 85821     tt9876160                Koridor bessmertiya
# 84695     tt8769300  Rise of the Footsoldier: Marbella
# 38575     tt0255265              Izpiti po nikoe vreme
#
#                           original_title  year date_published  \
# ...

# %%
movies.shape
# Out:
# (85855, 22)

# %%
movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
c = movies.corr()
sns.heatmap(c, cmap="BrBG",annot=True)
c
# Out:
#                       duration  avg_vote     votes  metascore  \
# duration              1.000000  0.242432  0.125618   0.210531
# avg_vote              0.242432  1.000000  0.166972   0.691338
# votes                 0.125618  0.166972  1.000000   0.194730
# metascore             0.210531  0.691338  0.194730   1.000000
# reviews_from_users    0.130836  0.138185  0.766237   0.126131
# reviews_from_critics  0.135465  0.200526  0.671635   0.236107
#
#                       reviews_from_users  reviews_from_critics
# duration                        0.130836              0.135465
# avg_vote                        0.138185              0.200526
# votes                           0.766237              0.671635
# metascore                       0.126131              0.236107
# reviews_from_users              1.000000              0.671634
# reviews_from_critics            0.671634              1.000000

# %%
ratings = pd.read_csv("data/IMDb ratings.csv")
ratings.sample(10)
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 46097     tt0422702                    6.6          121        6.1
# 43578     tt0365289                    6.3         1760        6.4
# 38338     tt0251426                    4.6          563        7.3
# 81235     tt6803946                    6.3          165        6.7
# 82170     tt7253188                    4.6          116        6.2
# 36099     tt0202223                    6.8          102        7.1
# 7387      tt0045171                    6.7          296        7.0
# 82729     tt7523010                    7.6         1819        7.8
# 73011     tt3882000                    6.7         2436        6.8
# 85606     tt9615278                    5.9          160        6.0
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 46097          6.0        16        4       15       22       23  ...
# 43578          7.0        71       85      251      534      409  ...
# ...

# %%
ratings.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6',
#        'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
# ...

# %%
len(ratings)
# Out:
# 85855

# %%
movies[movies['title'] == 'Interstellar']
# Out:
#       imdb_title_id         title original_title  year date_published  \
# 50294     tt0816692  Interstellar   Interstellar  2014     2014-11-06
#
#                           genre  duration          country language  \
# 50294  Adventure, Drama, Sci-Fi       169  USA, UK, Canada  English
#
#                 director  ...  \
# 50294  Christopher Nolan  ...
#
#                                                   actors  \
# 50294  Ellen Burstyn, Matthew McConaughey, Mackenzie ...
#
#                                              description avg_vote    votes  \
# 50294  A team of explorers travel through a wormhole ...      8.6  1449256
#
#             budget  usa_gross_income worlwide_gross_income metascore  \
# 50294  $ 165000000       $ 188020017           $ 696742056      74.0
#
#       reviews_from_users  reviews_from_critics
# 50294             4100.0                 625.0
#
# [1 rows x 22 columns]

# %%
ratings[ratings['imdb_title_id'] == 'tt0816692'].loc[:, 'allgenders_0age_avg_vote':'females_45age_avg_vote']
# Out:
#        allgenders_0age_avg_vote  allgenders_0age_votes  \
# 50294                       8.8                 1501.0
#
#        allgenders_18age_avg_vote  allgenders_18age_votes  \
# 50294                        8.9                369986.0
#
#        allgenders_30age_avg_vote  allgenders_30age_votes  \
# 50294                        8.5                456101.0
#
#        allgenders_45age_avg_vote  allgenders_45age_votes  \
# 50294                        8.0                 92728.0
#
#        males_allages_avg_vote  males_allages_votes  ...  males_45age_votes  \
# 50294                     8.6             847316.0  ...            77974.0
#
#        females_allages_avg_vote  females_allages_votes  females_0age_avg_vote  \
# 50294                       8.4               164821.0                    8.3
#
#        females_0age_votes  females_18age_avg_vote  females_18age_votes  \
# 50294               205.0                     8.6              67266.0
#
# ...

# %%
'Beneficio películas según género dentro y fuera de USA.'
