# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# MPG: Millas por galón
# MSRP: Precio de venta

df = pd.read_csv("HP_engine.csv")
df.sample(10)
# Out:
#           Make          Model  Year  Engine Fuel Type  Engine HP  \
# 2572     Honda          Civic  2016  regular unleaded      174.0
# 7696    Toyota          Prius  2015  regular unleaded      134.0
# 8520       Kia            Rio  2016  regular unleaded      138.0
# 8389    Toyota           RAV4  2016  regular unleaded      176.0
# 9734   Hyundai         Sonata  2016  regular unleaded      185.0
# 8597       Kia          Rondo  2008  regular unleaded      162.0
# 2539     Honda  Civic del Sol  1996  regular unleaded      125.0
# 3189  Cadillac            CT6  2017  regular unleaded      335.0
# 2158     Dodge        Caliber  2011  regular unleaded      158.0
# 7166   Lincoln      Navigator  2017  regular unleaded      380.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 2572               4.0         AUTOMATIC  front wheel drive              2.0
# 7696               4.0         AUTOMATIC  front wheel drive              4.0
# 8520               4.0            MANUAL  front wheel drive              4.0
# 8389               4.0         AUTOMATIC  front wheel drive              4.0
# 9734               4.0         AUTOMATIC  front wheel drive              4.0
# 8597               4.0         AUTOMATIC  front wheel drive              4.0
# 2539               4.0            MANUAL  front wheel drive              2.0
# 3189               6.0         AUTOMATIC    all wheel drive              4.0
# 2158               4.0         AUTOMATIC  front wheel drive              4.0
# 7166               6.0         AUTOMATIC   four wheel drive              4.0
#
#               Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 2572                      NaN      Compact          Coupe           41
# 7696         Hatchback,Hybrid      Compact  4dr Hatchback           48
# 8520                      NaN      Compact          Sedan           38
# 8389                Crossover      Midsize        4dr SUV           31
# 9734                      NaN      Midsize          Sedan           38
# 8597                      NaN      Compact          Wagon           26
# 2539                      NaN      Compact          Coupe           33
# 3189  Luxury,High-Performance        Large          Sedan           27
# 2158                      NaN      Compact          Wagon           27
# 7166                   Luxury        Large        4dr SUV           20
#
#       city mpg  Popularity   MSRP
# 2572        31        2202  22300
# 7696        51        2031  23215
# 8520        27        1720  14165
# 8389        24        2031  26270
# 9734        25        1439  21750
# 8597        19        1720  16395
# 2539        26        2202   2108
# 3189        18        1624  60395
# 2158        23        1851  18620
# 7166        15          61  74260

# %%
df.shape
# Out:
# (11914, 16)

# %%
# Correlación de Pearson
# -1 < r < 1

# Finding the relations between the variables.
plt.figure(figsize=(15,10))
c = df.corr()
sns.heatmap(c, cmap="BrBG",annot=True)
c
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine HP         0.351794   1.000000          0.779988        -0.102713
# Engine Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway MPG       0.258240  -0.406563         -0.621606         0.118570
# city mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.258240  0.198171    0.073049  0.227590
# Engine HP           -0.406563 -0.439371    0.037501  0.662008
# Engine Cylinders    -0.621606 -0.600776    0.041145  0.531312
# Number of Doors      0.118570  0.120881   -0.048272 -0.126635
# highway MPG          1.000000  0.886829   -0.020991 -0.160043
# city mpg             0.886829  1.000000   -0.003217 -0.157676
# Popularity          -0.020991 -0.003217    1.000000 -0.048476
# MSRP                -0.160043 -0.157676   -0.048476  1.000000

# %% [markdown]
# Correlación positiva --> (>0.5)
#
# Correlación negativa --> (<-0.45)

# %%
df.corr()
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine HP         0.351794   1.000000          0.779988        -0.102713
# Engine Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway MPG       0.258240  -0.406563         -0.621606         0.118570
# city mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.258240  0.198171    0.073049  0.227590
# Engine HP           -0.406563 -0.439371    0.037501  0.662008
# Engine Cylinders    -0.621606 -0.600776    0.041145  0.531312
# Number of Doors      0.118570  0.120881   -0.048272 -0.126635
# highway MPG          1.000000  0.886829   -0.020991 -0.160043
# city mpg             0.886829  1.000000   -0.003217 -0.157676
# Popularity          -0.020991 -0.003217    1.000000 -0.048476
# MSRP                -0.160043 -0.157676   -0.048476  1.000000

# %%
sns.heatmap(df.corr(), cmap="BrBG", annot=True)

# %% [markdown]
# ### Correlación de Pearson
# #### -1 < r < 1
# ![](correlation-examples.svg)
